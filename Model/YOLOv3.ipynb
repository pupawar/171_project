# %% [markdown]
# For details of YOLOv3, please refer to the paper: https://arxiv.org/pdf/1804.02767v1.pdf
#
# Source code: https://zhuanlan.zhihu.com/p/340300381 (Chinese)
#
# Or: https://github.com/YunYang1994/TensorFlow2.0-Examples/tree/master/4-Object_Detection/YOLOV3

# %% [markdown]
# ## Input all libraries here

# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import datetime
import re
import matplotlib.patches as patches
import seaborn as sns
import plotly.express as px
import plotly.figure_factory as ff
import tensorflow as tf
from sklearn.model_selection import train_test_split
from IPython.display import display
from PIL import Image
from tensorflow import keras
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import layers
from tensorflow.keras.layers import Conv2D, BatchNormalization, Activation, Add
from tensorflow.keras.layers import Input, LeakyReLU, Concatenate, UpSampling2D, ZeroPadding2D, GlobalAveragePooling2D, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.models import load_model
from tensorflow.keras.callbacks import ReduceLROnPlateau

# %% [markdown]
# ## Define darknet53 (backbone)

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.layers import Conv2D, BatchNormalization, Activation, Add

#Here we define a residual block to make it more convient to implement darknet53
def residual_block(x, num_filters, filter_size):
    # Shortcut connection
    shortcut = x

    # First convolutional layer (1x1 filter to reduce the number of channels)
    x = Conv2D(num_filters, (1, 1), padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    # Second convolutional layer (3x3 filter)
    x = Conv2D(num_filters * 2, (filter_size, filter_size), padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    # Adding the shortcut to the output
    x = Add()([x, shortcut])
    
    return x

def darknet53(input_layer):
    
    x = layers.Conv2D(32, (3, 3), strides=(1, 1), padding='same', activation='relu')(input_layer)
    x = layers.Conv2D(64, (3, 3), strides=(2, 2), padding='same', activation='relu')(x)
    
    for i in range(1):
        x = residual_block(x, 32, 3)
    
    x = layers.Conv2D(128, (3, 3), strides=(2, 2), padding='same', activation='relu')(x)
    
    for i in range(2):
        x = residual_block(x, 64, 3)
    
    x = layers.Conv2D(256, (3, 3), strides=(2, 2), padding='same', activation='relu')(x)
    
    for i in range(8):
        x = residual_block(x, 128, 3)
    route_1 = x
    
    x = layers.Conv2D(512, (3, 3), strides=(2, 2), padding='same', activation='relu')(x)
    
    for i in range(8):
        x = residual_block(x, 256, 3)
    route_2 = x
    
    x = layers.Conv2D(1024, (3, 3), strides=(2, 2), padding='same', activation='relu')(x)
    
    for i in range(4):
        x = residual_block(x, 512, 3)
    
    return route_1, route_2, x#The reason why we do this is because YOLOv3 extracts features in three different sizes

# %% [markdown]
# ## Define the remaining structure of YOLOv3

# %%
from tensorflow.keras.layers import Input, Conv2D, BatchNormalization, LeakyReLU, Concatenate, UpSampling2D, ZeroPadding2D, Concatenate

def YOLOv3(input_layer, num_classes=15):
    route_1, route_2, conv = darknet53(input_layer)

    #large size objects
    conv = Conv2D(512, (1, 1), strides=(1, 1), padding='same', use_bias=False, kernel_regularizer=tf.keras.regularizers.l2(0.0005))(conv)
    conv = BatchNormalization()(conv)
    conv = LeakyReLU(alpha=0.1)(conv)

    conv = Conv2D(1024, (3, 3), strides=(1, 1), padding='same', use_bias=False, kernel_regularizer=tf.keras.regularizers.l2(0.0005))(conv)
    conv = BatchNormalization()(conv)
    conv = LeakyReLU(alpha=0.1)(conv)

    conv = Conv2D(512, (1, 1), strides=(1, 1), padding='same', use_bias=False, kernel_regularizer=tf.keras.regularizers.l2(0.0005))(conv)
    conv = BatchNormalization()(conv)
    conv = LeakyReLU(alpha=0.1)(conv)

    conv = Conv2D(1024, (3, 3), strides=(1, 1), padding='same', use_bias=False, kernel_regularizer=tf.keras.regularizers.l2(0.0005))(conv)
    conv = BatchNormalization()(conv)
    conv = LeakyReLU(alpha=0.1)(conv)

    conv = Conv2D(512, (1, 1), strides=(1, 1), padding='same', use_bias=False, kernel_regularizer=tf.keras.regularizers.l2(0.0005))(conv)
    conv = BatchNormalization()(conv)
    conv = LeakyReLU(alpha=0.1)(conv)

    conv_lobj_branch = Conv2D(1024, (3, 3), strides=(1, 1), padding='same', use_bias=False, kernel_regularizer=tf.keras.regularizers.l2(0.0005))(conv)
    conv_lobj_branch = BatchNormalization()(conv_lobj_branch)
    conv_lobj_branch = LeakyReLU(alpha=0.1)(conv_lobj_branch)

    # Output for large-size objects
    conv_lbbox = Conv2D(3 * (num_classes + 5), (1, 1), strides=(1, 1), padding='same', use_bias=True)(conv_lobj_branch)
    
    
    #mid size objects
    conv = Conv2D(256, (1, 1), strides=(1, 1), padding='same', use_bias=False, kernel_regularizer=tf.keras.regularizers.l2(0.0005))(conv)
    conv = BatchNormalization()(conv)
    conv = LeakyReLU(alpha=0.1)(conv)

    # Upsampling and concatenation
    conv = UpSampling2D(size=(2, 2))(conv)
    conv = Concatenate()([conv, route_2])

    conv = Conv2D(256, (1, 1), strides=(1, 1), padding='same', use_bias=False, kernel_regularizer=tf.keras.regularizers.l2(0.0005))(conv)
    conv = BatchNormalization()(conv)
    conv = LeakyReLU(alpha=0.1)(conv)

    conv = Conv2D(512, (3, 3), strides=(1, 1), padding='same', use_bias=False, kernel_regularizer=tf.keras.regularizers.l2(0.0005))(conv)
    conv = BatchNormalization()(conv)
    conv = LeakyReLU(alpha=0.1)(conv)

    conv = Conv2D(256, (1, 1), strides=(1, 1), padding='same', use_bias=False, kernel_regularizer=tf.keras.regularizers.l2(0.0005))(conv)
    conv = BatchNormalization()(conv)
    conv = LeakyReLU(alpha=0.1)(conv)

    conv = Conv2D(512, (3, 3), strides=(1, 1), padding='same', use_bias=False, kernel_regularizer=tf.keras.regularizers.l2(0.0005))(conv)
    conv = BatchNormalization()(conv)
    conv = LeakyReLU(alpha=0.1)(conv)

    conv = Conv2D(256, (1, 1), strides=(1, 1), padding='same', use_bias=False, kernel_regularizer=tf.keras.regularizers.l2(0.0005))(conv)
    conv = BatchNormalization()(conv)
    conv = LeakyReLU(alpha=0.1)(conv)

    conv_mobj_branch = Conv2D(512, (3, 3), strides=(1, 1), padding='same', use_bias=False, kernel_regularizer=tf.keras.regularizers.l2(0.0005))(conv)
    conv_mobj_branch = BatchNormalization()(conv_mobj_branch)
    conv_mobj_branch = LeakyReLU(alpha=0.1)(conv_mobj_branch)

    # Output for mid-size objects
    conv_mbbox = Conv2D(3 * (num_classes + 5), (1, 1), strides=(1, 1), padding='same', use_bias=True)(conv_mobj_branch)
    
    
    #tiny size objects
    conv = UpSampling2D(size=(2, 2))(conv)
    conv = Concatenate()([conv, route_1])

    conv = Conv2D(128, (1, 1), strides=(1, 1), padding='same', use_bias=False, kernel_regularizer=tf.keras.regularizers.l2(0.0005))(conv)
    conv = BatchNormalization()(conv)
    conv = LeakyReLU(alpha=0.1)(conv)

    conv = Conv2D(256, (3, 3), strides=(1, 1), padding='same', use_bias=False, kernel_regularizer=tf.keras.regularizers.l2(0.0005))(conv)
    conv = BatchNormalization()(conv)
    conv = LeakyReLU(alpha=0.1)(conv)

    conv = Conv2D(128, (1, 1), strides=(1, 1), padding='same', use_bias=False, kernel_regularizer=tf.keras.regularizers.l2(0.0005))(conv)
    conv = BatchNormalization()(conv)
    conv = LeakyReLU(alpha=0.1)(conv)

    conv = Conv2D(256, (3, 3), strides=(1, 1), padding='same', use_bias=False, kernel_regularizer=tf.keras.regularizers.l2(0.0005))(conv)
    conv = BatchNormalization()(conv)
    conv = LeakyReLU(alpha=0.1)(conv)

    conv = Conv2D(128, (1, 1), strides=(1, 1), padding='same', use_bias=False, kernel_regularizer=tf.keras.regularizers.l2(0.0005))(conv)
    conv = BatchNormalization()(conv)
    conv = LeakyReLU(alpha=0.1)(conv)

    conv_sobj_branch = Conv2D(256, (3, 3), strides=(1, 1), padding='same', use_bias=False, kernel_regularizer=tf.keras.regularizers.l2(0.0005))(conv)
    conv_sobj_branch = BatchNormalization()(conv_sobj_branch)
    conv_sobj_branch = LeakyReLU(alpha=0.1)(conv_sobj_branch)

    # Output for tiny-size objects
    conv_sbbox = Conv2D(3 * (num_classes + 5), (1, 1), strides=(1, 1), padding='same', use_bias=True)(conv_sobj_branch)
    
    conv_sbbox = Conv2D(30, (1, 1), strides=(1, 1), padding='same', activation='linear')(conv_sbbox)
    conv_mbbox = Conv2D(30, (1, 1), strides=(1, 1), padding='same', activation='linear')(conv_mbbox)
    conv_lbbox = Conv2D(30, (1, 1), strides=(1, 1), padding='same', activation='linear')(conv_lbbox)
    
    model = Model(inputs = input_layer, outputs = [conv_sbbox, conv_mbbox, conv_lbbox])
    return model

# %% [markdown]
# ## Compile the model (here we slightly modify the NN to make it compatible with our output)

# %%
model = YOLOv3(Input(shape =(96, 96, 3)))

output1 = model.layers[-3].output  # 12*12*30
output2 = model.layers[-2].output  # 6*6*30
output3 = model.layers[-1].output  # 3*3*30

# Apply global average pooling to each output
pooled_output1 = GlobalAveragePooling2D()(output1)
pooled_output2 = GlobalAveragePooling2D()(output2)
pooled_output3 = GlobalAveragePooling2D()(output3)

# Concatenate the pooled outputs
concatenated_outputs = Concatenate()([pooled_output1, pooled_output2, pooled_output3])

# Fully connected layer to get the keypoints
keypoints = Dense(30, activation='linear')(concatenated_outputs)

# Create the new model
custom_model = Model(inputs=model.input, outputs=keypoints)

# Compile and train the model
custom_model.compile(optimizer = Adam(learning_rate = 0.001), loss='mean_squared_error')

# Print model summary
custom_model.summary()
# Out:
# Model: "model_31"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_47 (InputLayer)           [(None, 96, 96, 3)]  0
# __________________________________________________________________________________________________
# conv2d_2034 (Conv2D)            (None, 96, 96, 32)   896         input_47[0][0]
# __________________________________________________________________________________________________
# conv2d_2035 (Conv2D)            (None, 48, 48, 64)   18496       conv2d_2034[0][0]
# __________________________________________________________________________________________________
# conv2d_2036 (Conv2D)            (None, 48, 48, 32)   2080        conv2d_2035[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1695 (Batch (None, 48, 48, 32)   128         conv2d_2036[0][0]
# __________________________________________________________________________________________________
# activation_1334 (Activation)    (None, 48, 48, 32)   0           batch_normalization_1695[0][0]
# __________________________________________________________________________________________________
# conv2d_2037 (Conv2D)            (None, 48, 48, 64)   18496       activation_1334[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1696 (Batch (None, 48, 48, 64)   256         conv2d_2037[0][0]
# __________________________________________________________________________________________________
# activation_1335 (Activation)    (None, 48, 48, 64)   0           batch_normalization_1696[0][0]
# __________________________________________________________________________________________________
# add_667 (Add)                   (None, 48, 48, 64)   0           activation_1335[0][0]
#                                                                  conv2d_2035[0][0]
# __________________________________________________________________________________________________
# conv2d_2038 (Conv2D)            (None, 24, 24, 128)  73856       add_667[0][0]
# __________________________________________________________________________________________________
# conv2d_2039 (Conv2D)            (None, 24, 24, 64)   8256        conv2d_2038[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1697 (Batch (None, 24, 24, 64)   256         conv2d_2039[0][0]
# __________________________________________________________________________________________________
# activation_1336 (Activation)    (None, 24, 24, 64)   0           batch_normalization_1697[0][0]
# __________________________________________________________________________________________________
# conv2d_2040 (Conv2D)            (None, 24, 24, 128)  73856       activation_1336[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1698 (Batch (None, 24, 24, 128)  512         conv2d_2040[0][0]
# __________________________________________________________________________________________________
# activation_1337 (Activation)    (None, 24, 24, 128)  0           batch_normalization_1698[0][0]
# __________________________________________________________________________________________________
# add_668 (Add)                   (None, 24, 24, 128)  0           activation_1337[0][0]
#                                                                  conv2d_2038[0][0]
# __________________________________________________________________________________________________
# conv2d_2041 (Conv2D)            (None, 24, 24, 64)   8256        add_668[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1699 (Batch (None, 24, 24, 64)   256         conv2d_2041[0][0]
# __________________________________________________________________________________________________
# activation_1338 (Activation)    (None, 24, 24, 64)   0           batch_normalization_1699[0][0]
# __________________________________________________________________________________________________
# conv2d_2042 (Conv2D)            (None, 24, 24, 128)  73856       activation_1338[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1700 (Batch (None, 24, 24, 128)  512         conv2d_2042[0][0]
# __________________________________________________________________________________________________
# activation_1339 (Activation)    (None, 24, 24, 128)  0           batch_normalization_1700[0][0]
# __________________________________________________________________________________________________
# add_669 (Add)                   (None, 24, 24, 128)  0           activation_1339[0][0]
#                                                                  add_668[0][0]
# __________________________________________________________________________________________________
# conv2d_2043 (Conv2D)            (None, 12, 12, 256)  295168      add_669[0][0]
# __________________________________________________________________________________________________
# conv2d_2044 (Conv2D)            (None, 12, 12, 128)  32896       conv2d_2043[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1701 (Batch (None, 12, 12, 128)  512         conv2d_2044[0][0]
# __________________________________________________________________________________________________
# activation_1340 (Activation)    (None, 12, 12, 128)  0           batch_normalization_1701[0][0]
# __________________________________________________________________________________________________
# conv2d_2045 (Conv2D)            (None, 12, 12, 256)  295168      activation_1340[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1702 (Batch (None, 12, 12, 256)  1024        conv2d_2045[0][0]
# __________________________________________________________________________________________________
# activation_1341 (Activation)    (None, 12, 12, 256)  0           batch_normalization_1702[0][0]
# __________________________________________________________________________________________________
# add_670 (Add)                   (None, 12, 12, 256)  0           activation_1341[0][0]
#                                                                  conv2d_2043[0][0]
# __________________________________________________________________________________________________
# conv2d_2046 (Conv2D)            (None, 12, 12, 128)  32896       add_670[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1703 (Batch (None, 12, 12, 128)  512         conv2d_2046[0][0]
# __________________________________________________________________________________________________
# activation_1342 (Activation)    (None, 12, 12, 128)  0           batch_normalization_1703[0][0]
# __________________________________________________________________________________________________
# conv2d_2047 (Conv2D)            (None, 12, 12, 256)  295168      activation_1342[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1704 (Batch (None, 12, 12, 256)  1024        conv2d_2047[0][0]
# __________________________________________________________________________________________________
# activation_1343 (Activation)    (None, 12, 12, 256)  0           batch_normalization_1704[0][0]
# __________________________________________________________________________________________________
# add_671 (Add)                   (None, 12, 12, 256)  0           activation_1343[0][0]
#                                                                  add_670[0][0]
# __________________________________________________________________________________________________
# conv2d_2048 (Conv2D)            (None, 12, 12, 128)  32896       add_671[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1705 (Batch (None, 12, 12, 128)  512         conv2d_2048[0][0]
# __________________________________________________________________________________________________
# activation_1344 (Activation)    (None, 12, 12, 128)  0           batch_normalization_1705[0][0]
# __________________________________________________________________________________________________
# conv2d_2049 (Conv2D)            (None, 12, 12, 256)  295168      activation_1344[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1706 (Batch (None, 12, 12, 256)  1024        conv2d_2049[0][0]
# __________________________________________________________________________________________________
# activation_1345 (Activation)    (None, 12, 12, 256)  0           batch_normalization_1706[0][0]
# __________________________________________________________________________________________________
# add_672 (Add)                   (None, 12, 12, 256)  0           activation_1345[0][0]
#                                                                  add_671[0][0]
# __________________________________________________________________________________________________
# conv2d_2050 (Conv2D)            (None, 12, 12, 128)  32896       add_672[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1707 (Batch (None, 12, 12, 128)  512         conv2d_2050[0][0]
# __________________________________________________________________________________________________
# activation_1346 (Activation)    (None, 12, 12, 128)  0           batch_normalization_1707[0][0]
# __________________________________________________________________________________________________
# conv2d_2051 (Conv2D)            (None, 12, 12, 256)  295168      activation_1346[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1708 (Batch (None, 12, 12, 256)  1024        conv2d_2051[0][0]
# __________________________________________________________________________________________________
# activation_1347 (Activation)    (None, 12, 12, 256)  0           batch_normalization_1708[0][0]
# __________________________________________________________________________________________________
# add_673 (Add)                   (None, 12, 12, 256)  0           activation_1347[0][0]
#                                                                  add_672[0][0]
# __________________________________________________________________________________________________
# conv2d_2052 (Conv2D)            (None, 12, 12, 128)  32896       add_673[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1709 (Batch (None, 12, 12, 128)  512         conv2d_2052[0][0]
# __________________________________________________________________________________________________
# activation_1348 (Activation)    (None, 12, 12, 128)  0           batch_normalization_1709[0][0]
# __________________________________________________________________________________________________
# conv2d_2053 (Conv2D)            (None, 12, 12, 256)  295168      activation_1348[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1710 (Batch (None, 12, 12, 256)  1024        conv2d_2053[0][0]
# __________________________________________________________________________________________________
# activation_1349 (Activation)    (None, 12, 12, 256)  0           batch_normalization_1710[0][0]
# __________________________________________________________________________________________________
# add_674 (Add)                   (None, 12, 12, 256)  0           activation_1349[0][0]
#                                                                  add_673[0][0]
# __________________________________________________________________________________________________
# conv2d_2054 (Conv2D)            (None, 12, 12, 128)  32896       add_674[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1711 (Batch (None, 12, 12, 128)  512         conv2d_2054[0][0]
# __________________________________________________________________________________________________
# activation_1350 (Activation)    (None, 12, 12, 128)  0           batch_normalization_1711[0][0]
# __________________________________________________________________________________________________
# conv2d_2055 (Conv2D)            (None, 12, 12, 256)  295168      activation_1350[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1712 (Batch (None, 12, 12, 256)  1024        conv2d_2055[0][0]
# __________________________________________________________________________________________________
# activation_1351 (Activation)    (None, 12, 12, 256)  0           batch_normalization_1712[0][0]
# __________________________________________________________________________________________________
# add_675 (Add)                   (None, 12, 12, 256)  0           activation_1351[0][0]
#                                                                  add_674[0][0]
# __________________________________________________________________________________________________
# conv2d_2056 (Conv2D)            (None, 12, 12, 128)  32896       add_675[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1713 (Batch (None, 12, 12, 128)  512         conv2d_2056[0][0]
# __________________________________________________________________________________________________
# activation_1352 (Activation)    (None, 12, 12, 128)  0           batch_normalization_1713[0][0]
# __________________________________________________________________________________________________
# conv2d_2057 (Conv2D)            (None, 12, 12, 256)  295168      activation_1352[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1714 (Batch (None, 12, 12, 256)  1024        conv2d_2057[0][0]
# __________________________________________________________________________________________________
# activation_1353 (Activation)    (None, 12, 12, 256)  0           batch_normalization_1714[0][0]
# __________________________________________________________________________________________________
# add_676 (Add)                   (None, 12, 12, 256)  0           activation_1353[0][0]
#                                                                  add_675[0][0]
# __________________________________________________________________________________________________
# conv2d_2058 (Conv2D)            (None, 12, 12, 128)  32896       add_676[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1715 (Batch (None, 12, 12, 128)  512         conv2d_2058[0][0]
# __________________________________________________________________________________________________
# activation_1354 (Activation)    (None, 12, 12, 128)  0           batch_normalization_1715[0][0]
# __________________________________________________________________________________________________
# conv2d_2059 (Conv2D)            (None, 12, 12, 256)  295168      activation_1354[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1716 (Batch (None, 12, 12, 256)  1024        conv2d_2059[0][0]
# __________________________________________________________________________________________________
# activation_1355 (Activation)    (None, 12, 12, 256)  0           batch_normalization_1716[0][0]
# __________________________________________________________________________________________________
# add_677 (Add)                   (None, 12, 12, 256)  0           activation_1355[0][0]
#                                                                  add_676[0][0]
# __________________________________________________________________________________________________
# conv2d_2060 (Conv2D)            (None, 6, 6, 512)    1180160     add_677[0][0]
# __________________________________________________________________________________________________
# conv2d_2061 (Conv2D)            (None, 6, 6, 256)    131328      conv2d_2060[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1717 (Batch (None, 6, 6, 256)    1024        conv2d_2061[0][0]
# __________________________________________________________________________________________________
# activation_1356 (Activation)    (None, 6, 6, 256)    0           batch_normalization_1717[0][0]
# __________________________________________________________________________________________________
# conv2d_2062 (Conv2D)            (None, 6, 6, 512)    1180160     activation_1356[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1718 (Batch (None, 6, 6, 512)    2048        conv2d_2062[0][0]
# __________________________________________________________________________________________________
# activation_1357 (Activation)    (None, 6, 6, 512)    0           batch_normalization_1718[0][0]
# __________________________________________________________________________________________________
# add_678 (Add)                   (None, 6, 6, 512)    0           activation_1357[0][0]
#                                                                  conv2d_2060[0][0]
# __________________________________________________________________________________________________
# conv2d_2063 (Conv2D)            (None, 6, 6, 256)    131328      add_678[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1719 (Batch (None, 6, 6, 256)    1024        conv2d_2063[0][0]
# __________________________________________________________________________________________________
# activation_1358 (Activation)    (None, 6, 6, 256)    0           batch_normalization_1719[0][0]
# __________________________________________________________________________________________________
# conv2d_2064 (Conv2D)            (None, 6, 6, 512)    1180160     activation_1358[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1720 (Batch (None, 6, 6, 512)    2048        conv2d_2064[0][0]
# __________________________________________________________________________________________________
# activation_1359 (Activation)    (None, 6, 6, 512)    0           batch_normalization_1720[0][0]
# __________________________________________________________________________________________________
# add_679 (Add)                   (None, 6, 6, 512)    0           activation_1359[0][0]
#                                                                  add_678[0][0]
# __________________________________________________________________________________________________
# conv2d_2065 (Conv2D)            (None, 6, 6, 256)    131328      add_679[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1721 (Batch (None, 6, 6, 256)    1024        conv2d_2065[0][0]
# __________________________________________________________________________________________________
# activation_1360 (Activation)    (None, 6, 6, 256)    0           batch_normalization_1721[0][0]
# __________________________________________________________________________________________________
# conv2d_2066 (Conv2D)            (None, 6, 6, 512)    1180160     activation_1360[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1722 (Batch (None, 6, 6, 512)    2048        conv2d_2066[0][0]
# __________________________________________________________________________________________________
# activation_1361 (Activation)    (None, 6, 6, 512)    0           batch_normalization_1722[0][0]
# __________________________________________________________________________________________________
# add_680 (Add)                   (None, 6, 6, 512)    0           activation_1361[0][0]
#                                                                  add_679[0][0]
# __________________________________________________________________________________________________
# conv2d_2067 (Conv2D)            (None, 6, 6, 256)    131328      add_680[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1723 (Batch (None, 6, 6, 256)    1024        conv2d_2067[0][0]
# __________________________________________________________________________________________________
# activation_1362 (Activation)    (None, 6, 6, 256)    0           batch_normalization_1723[0][0]
# __________________________________________________________________________________________________
# conv2d_2068 (Conv2D)            (None, 6, 6, 512)    1180160     activation_1362[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1724 (Batch (None, 6, 6, 512)    2048        conv2d_2068[0][0]
# __________________________________________________________________________________________________
# activation_1363 (Activation)    (None, 6, 6, 512)    0           batch_normalization_1724[0][0]
# __________________________________________________________________________________________________
# add_681 (Add)                   (None, 6, 6, 512)    0           activation_1363[0][0]
#                                                                  add_680[0][0]
# __________________________________________________________________________________________________
# conv2d_2069 (Conv2D)            (None, 6, 6, 256)    131328      add_681[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1725 (Batch (None, 6, 6, 256)    1024        conv2d_2069[0][0]
# __________________________________________________________________________________________________
# activation_1364 (Activation)    (None, 6, 6, 256)    0           batch_normalization_1725[0][0]
# __________________________________________________________________________________________________
# conv2d_2070 (Conv2D)            (None, 6, 6, 512)    1180160     activation_1364[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1726 (Batch (None, 6, 6, 512)    2048        conv2d_2070[0][0]
# __________________________________________________________________________________________________
# activation_1365 (Activation)    (None, 6, 6, 512)    0           batch_normalization_1726[0][0]
# __________________________________________________________________________________________________
# add_682 (Add)                   (None, 6, 6, 512)    0           activation_1365[0][0]
#                                                                  add_681[0][0]
# __________________________________________________________________________________________________
# conv2d_2071 (Conv2D)            (None, 6, 6, 256)    131328      add_682[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1727 (Batch (None, 6, 6, 256)    1024        conv2d_2071[0][0]
# __________________________________________________________________________________________________
# activation_1366 (Activation)    (None, 6, 6, 256)    0           batch_normalization_1727[0][0]
# __________________________________________________________________________________________________
# conv2d_2072 (Conv2D)            (None, 6, 6, 512)    1180160     activation_1366[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1728 (Batch (None, 6, 6, 512)    2048        conv2d_2072[0][0]
# __________________________________________________________________________________________________
# activation_1367 (Activation)    (None, 6, 6, 512)    0           batch_normalization_1728[0][0]
# __________________________________________________________________________________________________
# add_683 (Add)                   (None, 6, 6, 512)    0           activation_1367[0][0]
#                                                                  add_682[0][0]
# __________________________________________________________________________________________________
# conv2d_2073 (Conv2D)            (None, 6, 6, 256)    131328      add_683[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1729 (Batch (None, 6, 6, 256)    1024        conv2d_2073[0][0]
# __________________________________________________________________________________________________
# activation_1368 (Activation)    (None, 6, 6, 256)    0           batch_normalization_1729[0][0]
# __________________________________________________________________________________________________
# conv2d_2074 (Conv2D)            (None, 6, 6, 512)    1180160     activation_1368[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1730 (Batch (None, 6, 6, 512)    2048        conv2d_2074[0][0]
# __________________________________________________________________________________________________
# activation_1369 (Activation)    (None, 6, 6, 512)    0           batch_normalization_1730[0][0]
# __________________________________________________________________________________________________
# add_684 (Add)                   (None, 6, 6, 512)    0           activation_1369[0][0]
#                                                                  add_683[0][0]
# __________________________________________________________________________________________________
# conv2d_2075 (Conv2D)            (None, 6, 6, 256)    131328      add_684[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1731 (Batch (None, 6, 6, 256)    1024        conv2d_2075[0][0]
# __________________________________________________________________________________________________
# activation_1370 (Activation)    (None, 6, 6, 256)    0           batch_normalization_1731[0][0]
# __________________________________________________________________________________________________
# conv2d_2076 (Conv2D)            (None, 6, 6, 512)    1180160     activation_1370[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1732 (Batch (None, 6, 6, 512)    2048        conv2d_2076[0][0]
# __________________________________________________________________________________________________
# activation_1371 (Activation)    (None, 6, 6, 512)    0           batch_normalization_1732[0][0]
# __________________________________________________________________________________________________
# add_685 (Add)                   (None, 6, 6, 512)    0           activation_1371[0][0]
#                                                                  add_684[0][0]
# __________________________________________________________________________________________________
# conv2d_2077 (Conv2D)            (None, 3, 3, 1024)   4719616     add_685[0][0]
# __________________________________________________________________________________________________
# conv2d_2078 (Conv2D)            (None, 3, 3, 512)    524800      conv2d_2077[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1733 (Batch (None, 3, 3, 512)    2048        conv2d_2078[0][0]
# __________________________________________________________________________________________________
# activation_1372 (Activation)    (None, 3, 3, 512)    0           batch_normalization_1733[0][0]
# __________________________________________________________________________________________________
# conv2d_2079 (Conv2D)            (None, 3, 3, 1024)   4719616     activation_1372[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1734 (Batch (None, 3, 3, 1024)   4096        conv2d_2079[0][0]
# __________________________________________________________________________________________________
# activation_1373 (Activation)    (None, 3, 3, 1024)   0           batch_normalization_1734[0][0]
# __________________________________________________________________________________________________
# add_686 (Add)                   (None, 3, 3, 1024)   0           activation_1373[0][0]
#                                                                  conv2d_2077[0][0]
# __________________________________________________________________________________________________
# conv2d_2080 (Conv2D)            (None, 3, 3, 512)    524800      add_686[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1735 (Batch (None, 3, 3, 512)    2048        conv2d_2080[0][0]
# __________________________________________________________________________________________________
# activation_1374 (Activation)    (None, 3, 3, 512)    0           batch_normalization_1735[0][0]
# __________________________________________________________________________________________________
# conv2d_2081 (Conv2D)            (None, 3, 3, 1024)   4719616     activation_1374[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1736 (Batch (None, 3, 3, 1024)   4096        conv2d_2081[0][0]
# __________________________________________________________________________________________________
# activation_1375 (Activation)    (None, 3, 3, 1024)   0           batch_normalization_1736[0][0]
# __________________________________________________________________________________________________
# add_687 (Add)                   (None, 3, 3, 1024)   0           activation_1375[0][0]
#                                                                  add_686[0][0]
# __________________________________________________________________________________________________
# conv2d_2082 (Conv2D)            (None, 3, 3, 512)    524800      add_687[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1737 (Batch (None, 3, 3, 512)    2048        conv2d_2082[0][0]
# __________________________________________________________________________________________________
# activation_1376 (Activation)    (None, 3, 3, 512)    0           batch_normalization_1737[0][0]
# __________________________________________________________________________________________________
# conv2d_2083 (Conv2D)            (None, 3, 3, 1024)   4719616     activation_1376[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1738 (Batch (None, 3, 3, 1024)   4096        conv2d_2083[0][0]
# __________________________________________________________________________________________________
# activation_1377 (Activation)    (None, 3, 3, 1024)   0           batch_normalization_1738[0][0]
# __________________________________________________________________________________________________
# add_688 (Add)                   (None, 3, 3, 1024)   0           activation_1377[0][0]
#                                                                  add_687[0][0]
# __________________________________________________________________________________________________
# conv2d_2084 (Conv2D)            (None, 3, 3, 512)    524800      add_688[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1739 (Batch (None, 3, 3, 512)    2048        conv2d_2084[0][0]
# __________________________________________________________________________________________________
# activation_1378 (Activation)    (None, 3, 3, 512)    0           batch_normalization_1739[0][0]
# __________________________________________________________________________________________________
# conv2d_2085 (Conv2D)            (None, 3, 3, 1024)   4719616     activation_1378[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1740 (Batch (None, 3, 3, 1024)   4096        conv2d_2085[0][0]
# __________________________________________________________________________________________________
# activation_1379 (Activation)    (None, 3, 3, 1024)   0           batch_normalization_1740[0][0]
# __________________________________________________________________________________________________
# add_689 (Add)                   (None, 3, 3, 1024)   0           activation_1379[0][0]
#                                                                  add_688[0][0]
# __________________________________________________________________________________________________
# conv2d_2086 (Conv2D)            (None, 3, 3, 512)    524288      add_689[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1741 (Batch (None, 3, 3, 512)    2048        conv2d_2086[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_361 (LeakyReLU)     (None, 3, 3, 512)    0           batch_normalization_1741[0][0]
# __________________________________________________________________________________________________
# conv2d_2087 (Conv2D)            (None, 3, 3, 1024)   4718592     leaky_re_lu_361[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1742 (Batch (None, 3, 3, 1024)   4096        conv2d_2087[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_362 (LeakyReLU)     (None, 3, 3, 1024)   0           batch_normalization_1742[0][0]
# __________________________________________________________________________________________________
# conv2d_2088 (Conv2D)            (None, 3, 3, 512)    524288      leaky_re_lu_362[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1743 (Batch (None, 3, 3, 512)    2048        conv2d_2088[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_363 (LeakyReLU)     (None, 3, 3, 512)    0           batch_normalization_1743[0][0]
# __________________________________________________________________________________________________
# conv2d_2089 (Conv2D)            (None, 3, 3, 1024)   4718592     leaky_re_lu_363[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1744 (Batch (None, 3, 3, 1024)   4096        conv2d_2089[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_364 (LeakyReLU)     (None, 3, 3, 1024)   0           batch_normalization_1744[0][0]
# __________________________________________________________________________________________________
# conv2d_2090 (Conv2D)            (None, 3, 3, 512)    524288      leaky_re_lu_364[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1745 (Batch (None, 3, 3, 512)    2048        conv2d_2090[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_365 (LeakyReLU)     (None, 3, 3, 512)    0           batch_normalization_1745[0][0]
# __________________________________________________________________________________________________
# conv2d_2093 (Conv2D)            (None, 3, 3, 256)    131072      leaky_re_lu_365[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1747 (Batch (None, 3, 3, 256)    1024        conv2d_2093[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_367 (LeakyReLU)     (None, 3, 3, 256)    0           batch_normalization_1747[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_38 (UpSampling2D) (None, 6, 6, 256)    0           leaky_re_lu_367[0][0]
# __________________________________________________________________________________________________
# concatenate_44 (Concatenate)    (None, 6, 6, 768)    0           up_sampling2d_38[0][0]
#                                                                  add_685[0][0]
# __________________________________________________________________________________________________
# conv2d_2094 (Conv2D)            (None, 6, 6, 256)    196608      concatenate_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1748 (Batch (None, 6, 6, 256)    1024        conv2d_2094[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_368 (LeakyReLU)     (None, 6, 6, 256)    0           batch_normalization_1748[0][0]
# __________________________________________________________________________________________________
# conv2d_2095 (Conv2D)            (None, 6, 6, 512)    1179648     leaky_re_lu_368[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1749 (Batch (None, 6, 6, 512)    2048        conv2d_2095[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_369 (LeakyReLU)     (None, 6, 6, 512)    0           batch_normalization_1749[0][0]
# __________________________________________________________________________________________________
# conv2d_2096 (Conv2D)            (None, 6, 6, 256)    131072      leaky_re_lu_369[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1750 (Batch (None, 6, 6, 256)    1024        conv2d_2096[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_370 (LeakyReLU)     (None, 6, 6, 256)    0           batch_normalization_1750[0][0]
# __________________________________________________________________________________________________
# conv2d_2097 (Conv2D)            (None, 6, 6, 512)    1179648     leaky_re_lu_370[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1751 (Batch (None, 6, 6, 512)    2048        conv2d_2097[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_371 (LeakyReLU)     (None, 6, 6, 512)    0           batch_normalization_1751[0][0]
# __________________________________________________________________________________________________
# conv2d_2098 (Conv2D)            (None, 6, 6, 256)    131072      leaky_re_lu_371[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1752 (Batch (None, 6, 6, 256)    1024        conv2d_2098[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_372 (LeakyReLU)     (None, 6, 6, 256)    0           batch_normalization_1752[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_39 (UpSampling2D) (None, 12, 12, 256)  0           leaky_re_lu_372[0][0]
# __________________________________________________________________________________________________
# concatenate_45 (Concatenate)    (None, 12, 12, 512)  0           up_sampling2d_39[0][0]
#                                                                  add_677[0][0]
# __________________________________________________________________________________________________
# conv2d_2101 (Conv2D)            (None, 12, 12, 128)  65536       concatenate_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1754 (Batch (None, 12, 12, 128)  512         conv2d_2101[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_374 (LeakyReLU)     (None, 12, 12, 128)  0           batch_normalization_1754[0][0]
# __________________________________________________________________________________________________
# conv2d_2102 (Conv2D)            (None, 12, 12, 256)  294912      leaky_re_lu_374[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1755 (Batch (None, 12, 12, 256)  1024        conv2d_2102[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_375 (LeakyReLU)     (None, 12, 12, 256)  0           batch_normalization_1755[0][0]
# __________________________________________________________________________________________________
# conv2d_2103 (Conv2D)            (None, 12, 12, 128)  32768       leaky_re_lu_375[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1756 (Batch (None, 12, 12, 128)  512         conv2d_2103[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_376 (LeakyReLU)     (None, 12, 12, 128)  0           batch_normalization_1756[0][0]
# __________________________________________________________________________________________________
# conv2d_2104 (Conv2D)            (None, 12, 12, 256)  294912      leaky_re_lu_376[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1757 (Batch (None, 12, 12, 256)  1024        conv2d_2104[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_377 (LeakyReLU)     (None, 12, 12, 256)  0           batch_normalization_1757[0][0]
# __________________________________________________________________________________________________
# conv2d_2105 (Conv2D)            (None, 12, 12, 128)  32768       leaky_re_lu_377[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1758 (Batch (None, 12, 12, 128)  512         conv2d_2105[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_378 (LeakyReLU)     (None, 12, 12, 128)  0           batch_normalization_1758[0][0]
# __________________________________________________________________________________________________
# conv2d_2106 (Conv2D)            (None, 12, 12, 256)  294912      leaky_re_lu_378[0][0]
# __________________________________________________________________________________________________
# conv2d_2099 (Conv2D)            (None, 6, 6, 512)    1179648     leaky_re_lu_372[0][0]
# __________________________________________________________________________________________________
# conv2d_2091 (Conv2D)            (None, 3, 3, 1024)   4718592     leaky_re_lu_365[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1759 (Batch (None, 12, 12, 256)  1024        conv2d_2106[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1753 (Batch (None, 6, 6, 512)    2048        conv2d_2099[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1746 (Batch (None, 3, 3, 1024)   4096        conv2d_2091[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_379 (LeakyReLU)     (None, 12, 12, 256)  0           batch_normalization_1759[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_373 (LeakyReLU)     (None, 6, 6, 512)    0           batch_normalization_1753[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_366 (LeakyReLU)     (None, 3, 3, 1024)   0           batch_normalization_1746[0][0]
# __________________________________________________________________________________________________
# conv2d_2107 (Conv2D)            (None, 12, 12, 60)   15420       leaky_re_lu_379[0][0]
# __________________________________________________________________________________________________
# conv2d_2100 (Conv2D)            (None, 6, 6, 60)     30780       leaky_re_lu_373[0][0]
# __________________________________________________________________________________________________
# conv2d_2092 (Conv2D)            (None, 3, 3, 60)     61500       leaky_re_lu_366[0][0]
# __________________________________________________________________________________________________
# conv2d_2108 (Conv2D)            (None, 12, 12, 30)   1830        conv2d_2107[0][0]
# __________________________________________________________________________________________________
# conv2d_2109 (Conv2D)            (None, 6, 6, 30)     1830        conv2d_2100[0][0]
# __________________________________________________________________________________________________
# conv2d_2110 (Conv2D)            (None, 3, 3, 30)     1830        conv2d_2092[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_18 (Gl (None, 30)           0           conv2d_2108[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_19 (Gl (None, 30)           0           conv2d_2109[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_20 (Gl (None, 30)           0           conv2d_2110[0][0]
# __________________________________________________________________________________________________
# concatenate_46 (Concatenate)    (None, 90)           0           global_average_pooling2d_18[0][0]
#                                                                  global_average_pooling2d_19[0][0]
#                                                                  global_average_pooling2d_20[0][0]
# __________________________________________________________________________________________________
# dense_13 (Dense)                (None, 30)           2730        concatenate_46[0][0]
# ==================================================================================================
# Total params: 61,652,848
# Trainable params: 61,604,528
# Non-trainable params: 48,320
# __________________________________________________________________________________________________

# %% [markdown]
# ## Define Useful Functions

# %%
def sort_pattern(s):
    return [int(text) if text.isdigit() else text.lower() for text in re.split(r'(\d+)', s)]

def sort_pattern(filename):
    # Extract numerical part of the filename for sorting, assuming the format 'name_number.jpg'
    num_part = ''.join(filter(str.isdigit, filename))
    return int(num_part) if num_part.isdigit() else float('inf')  # Return a large number if no digits found

def load_images(path):
    images = []
    file_list = os.listdir(path)
    sorted_files = sorted(file_list, key=sort_pattern)

    for filename in sorted_files:
        if filename.endswith(".jpg"):
            img_path = os.path.join(path, filename)
            # Open the image and convert it to grayscale
            img = Image.open(img_path).convert('L')
            # Convert the grayscale image to RGB
            img_rgb = img.convert('RGB')# The reason why we convert it to RGB is because 
            # Append the RGB image as a NumPy array to the images list
            images.append(np.array(img_rgb))
            img.close()

    return images

def show_keypoints(images, keypoints, n_rows=3, n_cols=7):
    fig, axes = plt.subplots(n_rows, n_cols, figsize=(2 * n_cols, 2 * n_rows), dpi=100)

    for i, ax in enumerate(axes.flatten()):
        img_array = np.array(images[i], dtype=np.uint8)  # Convert list of images to NumPy array
        img_array = img_array.squeeze()  # Remove singleton dimensions
        img = Image.fromarray(img_array)  # Convert NumPy array to PIL Image
        ax.imshow(img, cmap='gray')
        ax.set_title(f'Sample #{i}')

        for j in range(0, len(keypoints[i]), 2):
            x = keypoints[i][j]
            y = keypoints[i][j + 1]
            ax.plot(x, y, 'ro', markersize=2)

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## Train the model
# #### Here I did 100 epoches in my Spyder

# %%
train_data = pd.read_csv('training.csv')
path = r"images\train_images"
images = load_images(path)
#show_keypoints(images[:21], train_data.values[:21])

train_data.isna().mean().round(4) * 100
train_data.fillna(train_data.describe().T['50%'], inplace=True)
train_data.sample(5).T

x_train = np.array(images).reshape(-1, 96, 96, 3).astype('float64')
y_train = train_data.values.astype('float64')

# Reduce learning rate for improving convergence
# Dynamically adjust learning rate
reduce_LR = ReduceLROnPlateau(monitor='val_loss', factor=0.7, patience=5, min_lr=1e-15, mode='min', verbose=1)

callback = tf.keras.callbacks.TerminateOnNaN()
custom_model.fit(x_train, y_train, validation_split=0.2, epochs=1, callbacks=[reduce_LR], batch_size=32)

# Save the model
custom_model.save('YOLOv3.h5')
# Out:
# 177/177 [==============================] - 2048s 12s/step - loss: nan - val_loss: nan

# %% [markdown]
# ## Here is part of the training process
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ## Test the model with test images
# ### Here I directly use my trained "YOLOv3.h5" model to verify its performance

# %%
path = r"images\test_images"
test_img = load_images(path)
YOLOv3 = load_model('YOLOv3.h5')
test_img_array = np.stack(test_img, axis=0)  # Stack the list of images
x_test = test_img_array.reshape(-1, 96, 96, 3).astype('float64')
y_test = YOLOv3.predict(x_test).astype('float64')
print(y_test)
show_keypoints(x_test[:21], y_test[:21])
# Out:
# [[64.18325043 38.80130768 27.40563011 ... 68.04190063 46.98467636
#   84.54881287]
#  [65.94036865 35.95483017 27.79556656 ... 71.77458191 48.69662094
#   86.65818787]
#  [64.92922974 36.37556458 30.90304184 ... 70.5951004  48.78153992
#   84.81642151]
#  ...
#  [67.11767578 43.86543274 32.76242065 ... 71.71757507 46.87435913
#   78.04296875]
#  [63.40108871 36.50543976 32.46988678 ... 71.85940552 46.73244858
#   71.70439148]
#  [69.01396179 40.79524994 30.58985901 ... 72.01442719 47.65363693
#   81.03018188]]
